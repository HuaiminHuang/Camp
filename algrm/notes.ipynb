# %%
strs =["flower", "fly", "fix", ""]

prefix = strs[0]

# %%
len(prefix)
# Out:
# 6

# %%
p = prefix[0: len(prefix)-3]
strs[1].find(p)
# Out:
# -1

# %%
p = prefix[0: len(prefix)-4]
strs[1].find(p)
# Out:
# 0

# %%
p
# Out:
# 'fl'

# %%
word1 = strs[0] 
word2 = strs[1]

m = len(word1)
n = len(word2)
print(m, n)
# Out:
# 6 3

# %%
i=0
j=0
out = []
while i < m or j < n:
    if i < m: 
        out += word1[i]
        i += 1
    if j < n: 
        out += word2[j]
        j += 1

out
# Out:
# ['f', 'f', 'l', 'l', 'o', 'y', 'w', 'e', 'r']

# %%
str1 = "ABABABAB" 
str2 = "ABAB"

# %%
list(str1)
# Out:
# ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B']

# %%
set("aeiouAEIOU")
# Out:
# {'A', 'E', 'I', 'O', 'U', 'a', 'e', 'i', 'o', 'u'}

# %%
s1 = "a good   example"
word0 = s1.split()

# %%
word0[::-1]
# Out:
# ['example', 'good', 'a']
